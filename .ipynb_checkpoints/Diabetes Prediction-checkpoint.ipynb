# %% [markdown]
# # Diabetes predictive system

# %% [raw]
# This ML model uses data from patients to predict whether the patients are diabeteic or not.
# Some of the data points collected from patients are:
#         1. Pregnancies
#         2. Glucose
#         3. BloodPressure
#         4. SkinThickness
#         5. Insulin
#         6. BMI
#         7. DiabetesPedigreeFunction
#         8. Age

# %% [markdown]
# #### Import the required data analysis dependencies

# %%
import numpy as np
import statsmodels.api as sm
import pandas as pd 
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Import the required models . This is a supervised learning / classification problem.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import cross_val_score

# %% [markdown]
# #### Import model tuning and score metrics dependencies

# %%
from sklearn.preprocessing import StandardScaler # Standardizing our data
from sklearn.metrics import accuracy_score, confusion_matrix # Show how our model is performing

# %% [markdown]
# #### Loading our dataset

# %%
diabetes_data = pd.read_csv(r'E:\dev\ML\IBM\Data science\Data\Diabetes\Diabetes.csv')

diabetes_data.head().T
# Out:
#                                 0       1        2       3        4
# Pregnancies                 6.000   1.000    8.000   1.000    0.000
# Glucose                   148.000  85.000  183.000  89.000  137.000
# BloodPressure              72.000  66.000   64.000  66.000   40.000
# SkinThickness              35.000  29.000    0.000  23.000   35.000
# Insulin                     0.000   0.000    0.000  94.000  168.000
# BMI                        33.600  26.600   23.300  28.100   43.100
# DiabetesPedigreeFunction    0.627   0.351    0.672   0.167    2.288
# Age                        50.000  31.000   32.000  21.000   33.000
# Outcome                     1.000   0.000    1.000   0.000    1.000

# %% [markdown]
# #### Check pairwise correlation using scatter plot from seaborn

# %%
diabetes_data_scatter_plots = sns.pairplot(diabetes_data)
diabetes_data_scatter_plots

# %% [markdown]
# #### Check pairwise correlation of Pregnancies, BloodPressure, BMI , Age and Outcome

# %%
scatterplot = sns.pairplot(diabetes_data[['Pregnancies','BloodPressure','BMI','Age','Outcome']], hue='Outcome', height = 5, kind='reg')
scatterplot

# %% [markdown]
# #### Analyze pregnancies and check out the outliers

# %%
pregnancy_data = diabetes_data['Pregnancies'].values
pregnancy_data_box_plots = plt.boxplot(pregnancy_data)

print('The median Pregnancies is : ', diabetes_data['Pregnancies'].median() )
# Out:
# The median Pregnancies is :  3.0

# %%
pregnancy_data_box_plots.keys()
# Out:
# dict_keys(['whiskers', 'caps', 'boxes', 'medians', 'fliers', 'means'])

# %%
for key in pregnancy_data_box_plots:
    print(f'{key}:{[item.get_ydata() for item in pregnancy_data_box_plots[key]]}')
# Out:
# whiskers:[array([1., 0.]), array([ 6., 13.])]
# caps:[array([0., 0.]), array([13., 13.])]
# boxes:[array([1., 1., 6., 6., 1.])]
# medians:[array([3., 3.])]
# fliers:[array([15, 17, 14, 14], dtype=int64)]
# means:[]

# %% [markdown]
# #### As seen above, 14, 15 and 17 are outliers which ought to be removed from the dataset

# %%
for outlier_pregnancy in pregnancy_data:
    if outlier_pregnancy > 13:
        print(outlier_pregnancy)
# Out:
# 15
# 17
# 14
# 14

# %% [markdown]
# ##### We remove the outliers by selecting the clean data using the loc function

# %%
diabetes_data = diabetes_data.loc[diabetes_data['Pregnancies'].values <14]

# %%
pregnancy_data = diabetes_data['Pregnancies'].values
pregnancy_data_box_plots = sns.boxplot(pregnancy_data)

print('The median Pregnancies is : ', diabetes_data['Pregnancies'].median() )
# Out:
# The median Pregnancies is :  3.0

# %% [markdown]
# #### Get the dataset statistics using the describe function, value_counts to get the number of datapoints in a dataset group

# %%
# get the statistics of the whole group
diabetes_data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   764.000000  764.000000     764.000000     764.000000  764.000000
# mean      3.786649  120.776178      69.098168      20.476440   79.683246
# std       3.278714   31.946234      19.401789      15.966814  115.436078
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   27.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.250000
# max      13.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  764.000000                764.000000  764.000000  764.000000
# mean    31.966099                  0.472260   33.187173    0.345550
# std      7.894034                  0.331619   11.764745    0.475859
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.244000   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.500000                  0.626250   40.250000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# #### Convert the outcome from 1's and 0's to Yes or No

# %%
#diabetes_data['Outcome'].replace({0:'N', 1:'Y'}, inplace=True)

# %%
# get the number of those with diabetes and those without
diabetes_data['Outcome'].value_counts()
# Out:
# 0    500
# 1    264
# Name: Outcome, dtype: int64

# %% [markdown]
# #### Get the mean of all data points and group them by outcome

# %%
diabetes_data.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.712121  141.223485      70.829545      22.015152  100.310606
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.113636                  0.552803  36.969697

# %% [markdown]
# #### info() function shows the columns data types, number of null values and the number of dataset entries

# %%
diabetes_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 764 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               764 non-null    int64
#  1   Glucose                   764 non-null    int64
#  2   BloodPressure             764 non-null    int64
#  3   SkinThickness             764 non-null    int64
#  4   Insulin                   764 non-null    int64
#  5   BMI                       764 non-null    float64
#  6   DiabetesPedigreeFunction  764 non-null    float64
#  7   Age                       764 non-null    int64
#  8   Outcome                   764 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 59.7 KB

# %% [markdown]
# ####  Get the number of unique values in each column

# %%
for column in diabetes_data:
    unique_values = np.unique(diabetes_data[column])
    number_of_column_features = len(unique_values)
    if number_of_column_features > 10:
        print(column, 'has ',number_of_column_features, 'values.' )
    else:
        print(column, 'has ',number_of_column_features, 'values.......',unique_values )
# Out:
# Pregnancies has  14 values.
# Glucose has  136 values.
# BloodPressure has  47 values.
# SkinThickness has  51 values.
# Insulin has  185 values.
# BMI has  248 values.
# DiabetesPedigreeFunction has  516 values.
# Age has  52 values.
# Outcome has  2 values....... [0 1]

# %% [markdown]
# #### Show pairwise correlations of the datapoints using a correlation matrix

# %%
sns.set(rc={'figure.figsize':(15,10)})
ml_correlation_variables = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age','Outcome']
peason_correlation = diabetes_data[ml_correlation_variables].corr(method='pearson')
cols = ml_correlation_variables
ax = sns.heatmap(peason_correlation, annot=True, yticklabels=cols, xticklabels=cols, annot_kws={'size':10}, cmap='twilight_r')

# %%
diabetes_data.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.120529       0.144242      -0.097847
# Glucose                      0.120529  1.000000       0.154071       0.053875
# BloodPressure                0.144242  0.154071       1.000000       0.207595
# SkinThickness               -0.097847  0.053875       0.207595       1.000000
# Insulin                     -0.079443  0.334445       0.088091       0.437400
# BMI                          0.006171  0.219821       0.281744       0.390889
# DiabetesPedigreeFunction    -0.031852  0.138437       0.040934       0.184397
# Age                          0.546169  0.262493       0.239383      -0.117893
# Outcome                      0.205240  0.465391       0.064886       0.070071
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.079443  0.006171                 -0.031852
# Glucose                   0.334445  0.219821                  0.138437
# BloodPressure             0.088091  0.281744                  0.040934
# SkinThickness             0.437400  0.390889                  0.184397
# Insulin                   1.000000  0.197148                  0.184999
# BMI                       0.197148  1.000000                  0.140711
# DiabetesPedigreeFunction  0.184999  0.140711                  1.000000
# Age                      -0.043957  0.032986                  0.033822
# Outcome                   0.129928  0.289917                  0.176598
#
#                                Age   Outcome
# Pregnancies               0.546169  0.205240
# Glucose                   0.262493  0.465391
# BloodPressure             0.239383  0.064886
# SkinThickness            -0.117893  0.070071
# Insulin                  -0.043957  0.129928
# BMI                       0.032986  0.289917
# DiabetesPedigreeFunction  0.033822  0.176598
# Age                       1.000000  0.233776
# Outcome                   0.233776  1.000000

# %% [markdown]
# #### Divide the data into X and Y and find feature importance using DecisionTreeRegressor

# %%
X = diabetes_data.drop(columns = 'Outcome', axis = 1)
Y = diabetes_data['Outcome']

print (X.shape, Y.shape)
# Out:
# (764, 8) (764,)

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor()
# fit the model
model.fit(X, Y)
# get importance
importance = model.feature_importances_
# summarize feature importance

for column,score in enumerate(importance):
    #print('Feature: %0d, Score: %.5f' % (i,v))
    print(column, score)
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# 0 0.06925965462404181
# 1 0.3175666161184515
# 2 0.08382875235436502
# 3 0.03896111666111667
# 4 0.05078617590156929
# 5 0.1913051239335198
# 6 0.1320270253529242
# 7 0.11626553505401173

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y)
DT_classifier = DecisionTreeClassifier(random_state=20).fit(X_train, Y_train)
feature_importance =  DT_classifier.feature_importances_

feature_importance = 100*(feature_importance / feature_importance.max())

sorted_index = np.argsort(feature_importance)

pos = np.arange(sorted_index.shape[0]) + 5

plt.subplot(1,2,2)

plt.barh(pos, feature_importance[sorted_index], align = 'center')

plt.yticks(pos,diabetes_data.columns[sorted_index] )

plt.xlabel('Relative importance')

plt.title('Feature importance')

plt.show()

# %%
feature_importance
# Out:
# array([ 28.48625208, 100.        ,  13.57909999,  11.56625052,
#         27.98508097,  88.20853071,  50.93681578,  47.36382966])

# %%
df = pd.DataFrame(['Feature_name', X.columns, 'Importance',feature_importance])
df.T
# Out:
#               0                                                  1  \
# 0  Feature_name  Index(['Pregnancies', 'Glucose', 'BloodPressur...
#
#             2                                                  3
# 0  Importance  [28.48625208408856, 100.0, 13.579099994158739,...

# %% [markdown]
# #### The 5 Important features are
#     1. Glucose
#     2. BMI
#     3. DiabetesPedigreeFunction
#     4. Age
#     5. BloodPressure

# %%
important_features = ['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']
X = diabetes_data[important_features]
Y = diabetes_data['Outcome']

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# 2                       0.672   32
# 3                       0.167   21
# 4                       2.288   33
# ..                        ...  ...
# 763                     0.171   63
# 764                     0.340   27
# 765                     0.245   30
# 766                     0.349   47
# 767                     0.315   23
#
# [764 rows x 8 columns]

# %% [markdown]
# ####  Scale the X values to a standard scale to avoid skewness

# %%
scaler = StandardScaler()
scaler.fit(X)

standardized_diabetes_data = scaler.transform(X)

# %%
X = standardized_diabetes_data
X
# Out:
# array([[ 0.67550897,  0.8527345 ,  0.14966318, ...,  0.20711476,
#          0.46692355,  1.43002178],
#        [-0.85047818, -1.1206208 , -0.15978924, ..., -0.68021178,
#         -0.36590113, -0.18603086],
#        [ 1.28590383,  1.94904299, -0.26294005, ..., -1.09852286,
#          0.60271018, -0.10097546],
#        ...,
#        [ 0.37031154,  0.0070108 ,  0.14966318, ..., -0.73091615,
#         -0.68575409, -0.27108626],
#        [-0.85047818,  0.1636263 , -0.46924167, ..., -0.23654851,
#         -0.3719361 ,  1.17485557],
#        [-0.85047818, -0.870036  ,  0.04651237, ..., -0.19852023,
#         -0.47453044, -0.86647407]])

# %% [markdown]
# #### Split the data using train_test_split from model_selection

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y)

print(X_train.shape,  X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (611, 8) (153, 8) (611,) (153,)

# %% [markdown]
# #### The split is as follows:
#             X        Y
#     Train   611      611
#
#     Test    153      153

# %% [markdown]
# ### Model selection

# %%
models = [
        DecisionTreeClassifier(),
        LogisticRegression(max_iter = 1000),
        KNeighborsClassifier(),
        RandomForestClassifier(),
        SVC(kernel =  'linear')
]

# %% [markdown]
# #### Fit the models with data and evaluate their scores

# %%
def compare_models_with_train_test_split():
    for model in models:
        model.fit(X_train, Y_train)
        predicted_values = model.predict(X_test)
        accuracy = accuracy_score(Y_test, predicted_values)
        print('Accuracy of ' , model , 'is ----', accuracy)

# %%
compare_models_with_train_test_split()
# Out:
# Accuracy of  DecisionTreeClassifier() is ---- 0.6797385620915033
# Accuracy of  LogisticRegression(max_iter=1000) is ---- 0.7581699346405228
# Accuracy of  KNeighborsClassifier() is ---- 0.7124183006535948
# Accuracy of  RandomForestClassifier() is ---- 0.7777777777777778
# Accuracy of  SVC(kernel='linear') is ---- 0.7581699346405228

# %% [markdown]
# #### Compare models with KFold cross validation

# %%
def compare_models_with_cross_validation():
    for model in models:
        cv_score = cross_val_score(model, X, Y, cv=5)
        mean_accuracy = sum(cv_score) / len(cv_score)
        mean_accuracy = mean_accuracy * 100
        mean_accuracy = round(mean_accuracy, 2)
        print('Accuracy for ', model , 'is ', cv_score)
        print('Mean accuracy for ', model, 'is ', mean_accuracy, ' %')
        print('*****************************************************')

# %%
compare_models_with_cross_validation()
# Out:
# Accuracy for  DecisionTreeClassifier() is  [0.65359477 0.68627451 0.68627451 0.77124183 0.66447368]
# Mean accuracy for  DecisionTreeClassifier() is  69.24  %
# *****************************************************
# Accuracy for  LogisticRegression(max_iter=1000) is  [0.77777778 0.75816993 0.75163399 0.80392157 0.77631579]
# Mean accuracy for  LogisticRegression(max_iter=1000) is  77.36  %
# *****************************************************
# Accuracy for  KNeighborsClassifier() is  [0.7254902  0.73856209 0.7124183  0.77124183 0.72368421]
# Mean accuracy for  KNeighborsClassifier() is  73.43  %
# *****************************************************
# Accuracy for  RandomForestClassifier() is  [0.75163399 0.73202614 0.75816993 0.81699346 0.76315789]
# Mean accuracy for  RandomForestClassifier() is  76.44  %
# *****************************************************
# Accuracy for  SVC(kernel='linear') is  [0.77124183 0.75816993 0.75816993 0.81045752 0.76315789]
# Mean accuracy for  SVC(kernel='linear') is  77.22  %
# *****************************************************

# %%
lm = sm.OLS(Y_train,X_train)
results = lm.fit()
results.params
# Out:
# x1    0.052075
# x2    0.185964
# x3   -0.034785
# x4   -0.010459
# x5   -0.024485
# x6    0.111695
# x7    0.062230
# x8    0.021709
# dtype: float64

# %% [markdown]
# #### Draw the OLS regression summary sheet

# %%
print (results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                Outcome   R-squared (uncentered):                   0.197
# Model:                            OLS   Adj. R-squared (uncentered):              0.186
# Method:                 Least Squares   F-statistic:                              18.49
# Date:                Tue, 18 Jul 2023   Prob (F-statistic):                    6.96e-25
# Time:                        18:44:01   Log-Likelihood:                         -475.13
# No. Observations:                 611   AIC:                                      966.3
# Df Residuals:                     603   BIC:                                      1002.
# Df Model:                           8
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0521      0.026      2.003      0.046       0.001       0.103
# x2             0.1860      0.024      7.773      0.000       0.139       0.233
# x3            -0.0348      0.024     -1.456      0.146      -0.082       0.012
# x4            -0.0105      0.026     -0.401      0.689      -0.062       0.041
# x5            -0.0245      0.026     -0.957      0.339      -0.075       0.026
# x6             0.1117      0.025      4.471      0.000       0.063       0.161
# x7             0.0622      0.022      2.807      0.005       0.019       0.106
# x8             0.0217      0.026      0.823      0.411      -0.030       0.073
# ==============================================================================
# Omnibus:                       33.437   Durbin-Watson:                   1.188
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               25.258
# Skew:                           0.400   Prob(JB):                     3.28e-06
# Kurtosis:                       2.405   Cond. No.                         2.29
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### The OLS summary shows how the performance of LinearRegression model. As it stands, it's not performing any better than other models.

# %% [markdown]
# ### Check the confusion matrix of all models to see which one stands the best

# %%
def draw_confusion_matrix():
    for model in models:
        model.fit(X_train, Y_train)
        predicted_values = model.predict(X_test)
        cf_matrix = confusion_matrix(Y_test, predicted_values)
        tn, tp, fn, fp = cf_matrix.ravel()
        plt.figure(figsize=(8,4))
        sns.heatmap(cf_matrix, annot=True)
        
        plt.ylabel('True Values')
        plt.xlabel('Predicted Values')

# %%
draw_confusion_matrix()

# %% [markdown]
# #### Below are the average results of the confusion matrices
#
#      CLASSIFIER                 TRUE_PREDICTED    WRONG_PREDICTED
#
#      DecisionTreeClassifier()          112            41
#      LogisticRegression()              120            33
#      KNeighborsClassifier()            114            39
#      RandomForestClassifier            105            38
#      SVC(kernel =  'linear')           119            34

# %% [markdown]
# ### LogisticRegression() is the best as seen above, so we select it as our production model

# %%
    production_model =  LogisticRegression(max_iter=1000)
    cv_score = cross_val_score(production_model, X, Y, cv=5)
    mean_accuracy = sum(cv_score) / len(cv_score)
    mean_accuracy = mean_accuracy * 100
    mean_accuracy = round(mean_accuracy, 2)
    print('Accuracy for ', production_model , 'is ', cv_score)
    print('Mean accuracy for ', production_model, 'is ', mean_accuracy, ' %')
    print('*****************************************************')
# Out:
# Accuracy for  LogisticRegression(max_iter=1000) is  [0.77777778 0.75816993 0.75163399 0.80392157 0.77631579]
# Mean accuracy for  LogisticRegression(max_iter=1000) is  77.36  %
# *****************************************************

# %% [markdown]
# # Saving the model for deployment

# %%
import pickle

filename = 'Diabetes_Prediction_System.sav'

pickle.dump(production_model, open(filename, 'wb')) # wb means write binary ----

# %%
# loading the model

diabetes_prediction_model = pickle.load(open('Diabetes_Prediction_System.sav', 'rb')) # rb means read binary

# %%
input_data = (1,103,30,38,83,43.3,0.183,33)
diabetes_prediction_model.fit(X_train, Y_train)
input_data_as_numpy_array = np.asarray(input_data)

reshaped_input_data = input_data_as_numpy_array.reshape(1, -1)

std_data = scaler.transform(reshaped_input_data)

prediction = diabetes_prediction_model.predict(std_data)

print(prediction)

if prediction[0]==0:
    print('This person is healthy')
else:
    print('This person is diabetic')
# Out:
# [0]
# This person is healthy
